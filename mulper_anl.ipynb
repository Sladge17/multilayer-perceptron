# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mp_learn.learn import *

# %%
df = pd.read_csv('data.csv', header=None)
df.head(10)
# Out:
#          0  1      2      3       4       5        6        7        8   \
# 0    842302  M  17.99  10.38  122.80  1001.0  0.11840  0.27760  0.30010
# 1    842517  M  20.57  17.77  132.90  1326.0  0.08474  0.07864  0.08690
# 2  84300903  M  19.69  21.25  130.00  1203.0  0.10960  0.15990  0.19740
# 3  84348301  M  11.42  20.38   77.58   386.1  0.14250  0.28390  0.24140
# 4  84358402  M  20.29  14.34  135.10  1297.0  0.10030  0.13280  0.19800
# 5    843786  M  12.45  15.70   82.57   477.1  0.12780  0.17000  0.15780
# 6    844359  M  18.25  19.98  119.60  1040.0  0.09463  0.10900  0.11270
# 7  84458202  M  13.71  20.83   90.20   577.9  0.11890  0.16450  0.09366
# 8    844981  M  13.00  21.82   87.50   519.8  0.12730  0.19320  0.18590
# 9  84501001  M  12.46  24.04   83.97   475.9  0.11860  0.23960  0.22730
#
#         9    ...        22     23      24      25      26      27      28  \
# 0  0.14710   ...     25.38  17.33  184.60  2019.0  0.1622  0.6656  0.7119
# 1  0.07017   ...     24.99  23.41  158.80  1956.0  0.1238  0.1866  0.2416
# 2  0.12790   ...     23.57  25.53  152.50  1709.0  0.1444  0.4245  0.4504
# 3  0.10520   ...     14.91  26.50   98.87   567.7  0.2098  0.8663  0.6869
# 4  0.10430   ...     22.54  16.67  152.20  1575.0  0.1374  0.2050  0.4000
# 5  0.08089   ...     15.47  23.75  103.40   741.6  0.1791  0.5249  0.5355
# 6  0.07400   ...     22.88  27.66  153.20  1606.0  0.1442  0.2576  0.3784
# 7  0.05985   ...     17.06  28.14  110.60   897.0  0.1654  0.3682  0.2678
# 8  0.09353   ...     15.49  30.73  106.20   739.3  0.1703  0.5401  0.5390
# 9  0.08543   ...     15.09  40.68   97.65   711.4  0.1853  1.0580  1.1050
#
#        29      30       31
# 0  0.2654  0.4601  0.11890
# 1  0.1860  0.2750  0.08902
# 2  0.2430  0.3613  0.08758
# 3  0.2575  0.6638  0.17300
# 4  0.1625  0.2364  0.07678
# 5  0.1741  0.3985  0.12440
# 6  0.1932  0.3063  0.08368
# 7  0.1556  0.3196  0.11510
# 8  0.2060  0.4378  0.10720
# 9  0.2210  0.4366  0.20750
#
# [10 rows x 32 columns]

# %%
df.shape
# Out:
# (569, 32)

# %%
df.describe()
# Out:
#                  0           2           3           4            5   \
# count  5.690000e+02  569.000000  569.000000  569.000000   569.000000
# mean   3.037183e+07   14.127292   19.289649   91.969033   654.889104
# std    1.250206e+08    3.524049    4.301036   24.298981   351.914129
# min    8.670000e+03    6.981000    9.710000   43.790000   143.500000
# 25%    8.692180e+05   11.700000   16.170000   75.170000   420.300000
# 50%    9.060240e+05   13.370000   18.840000   86.240000   551.100000
# 75%    8.813129e+06   15.780000   21.800000  104.100000   782.700000
# max    9.113205e+08   28.110000   39.280000  188.500000  2501.000000
#
#                6           7           8           9           10     ...      \
# count  569.000000  569.000000  569.000000  569.000000  569.000000     ...
# mean     0.096360    0.104341    0.088799    0.048919    0.181162     ...
# std      0.014064    0.052813    0.079720    0.038803    0.027414     ...
# min      0.052630    0.019380    0.000000    0.000000    0.106000     ...
# 25%      0.086370    0.064920    0.029560    0.020310    0.161900     ...
# 50%      0.095870    0.092630    0.061540    0.033500    0.179200     ...
# 75%      0.105300    0.130400    0.130700    0.074000    0.195700     ...
# max      0.163400    0.345400    0.426800    0.201200    0.304000     ...
#
#                22          23          24           25          26  \
# count  569.000000  569.000000  569.000000   569.000000  569.000000
# mean    16.269190   25.677223  107.261213   880.583128    0.132369
# std      4.833242    6.146258   33.602542   569.356993    0.022832
# min      7.930000   12.020000   50.410000   185.200000    0.071170
# 25%     13.010000   21.080000   84.110000   515.300000    0.116600
# 50%     14.970000   25.410000   97.660000   686.500000    0.131300
# 75%     18.790000   29.720000  125.400000  1084.000000    0.146000
# max     36.040000   49.540000  251.200000  4254.000000    0.222600
#
#                27          28          29          30          31
# count  569.000000  569.000000  569.000000  569.000000  569.000000
# mean     0.254265    0.272188    0.114606    0.290076    0.083946
# std      0.157336    0.208624    0.065732    0.061867    0.018061
# min      0.027290    0.000000    0.000000    0.156500    0.055040
# 25%      0.147200    0.114500    0.064930    0.250400    0.071460
# 50%      0.211900    0.226700    0.099930    0.282200    0.080040
# 75%      0.339100    0.382900    0.161400    0.317900    0.092080
# max      1.058000    1.252000    0.291000    0.663800    0.207500
#
# [8 rows x 31 columns]

# %%
df.shape[0] - df.dropna().shape[0]
# Out:
# 0

# %%
df[1].unique()
# Out:
# array(['M', 'B'], dtype=object)

# %%
percent_test = 20
border_test = int(df.shape[0] * (100 - percent_test) * 0.01)
df_train = df.iloc[:border_test]
df_test = df.iloc[border_test:]

# %%
y_train = df_train[1]

# %%
# x_drop = list(set(range(df.shape[1])) - {2, 3})
x_drop = list(set(range(df.shape[1])) - {2, 3, 6, 7, 10, 11, 13})
x_train = df_train.drop(x_drop, axis=1)
x_train.head()
# Out:
#       2      3        6        7       10       11      13
# 0  17.99  10.38  0.11840  0.27760  0.2419  0.07871  0.9053
# 1  20.57  17.77  0.08474  0.07864  0.1812  0.05667  0.7339
# 2  19.69  21.25  0.10960  0.15990  0.2069  0.05999  0.7869
# 3  11.42  20.38  0.14250  0.28390  0.2597  0.09744  1.1560
# 4  20.29  14.34  0.10030  0.13280  0.1809  0.05883  0.7813

# %%
tmp = pd.concat([y_train, x_train], axis=1)
tmp.columns = list(range(1 + x_train.shape[1]))
plt.scatter(tmp[tmp[0] == 'M'][1], tmp[tmp[0] == 'M'][2], s=10)
plt.scatter(tmp[tmp[0] == 'B'][1], tmp[tmp[0] == 'B'][2], s=10)
plt.ylabel('x1')
plt.grid()
plt.show()

# %%
# x_train = x_train - x_train.describe().T['mean']
x_train = (x_train - x_train.describe().T['mean']) / x_train.describe().T['std']
# x_train = (x_train - x_train.describe().T['50%']) / x_train.describe().T['std']

# %%
tmp = pd.concat([y_train, x_train], axis=1)
tmp.columns = list(range(1 + x_train.shape[1]))
plt.scatter(tmp[tmp[0] == 'M'][1], tmp[tmp[0] == 'M'][2], s=10)
plt.scatter(tmp[tmp[0] == 'B'][1], tmp[tmp[0] == 'B'][2], s=10)
plt.ylabel('x1')
plt.grid()
plt.show()

# %%
def get_binary(target):
    target = list(map(lambda x: [1, 0] if x == 'M' else [0, 1], target))
    target = np.array(target, np.int8)
    return target

y_train = get_binary(y_train)
x_train = x_train.values

# %%
# def normalization(target, val_min, val_max):
#     return (target - val_min) / (val_max - val_min)

# def set_normxtrain(x_train, xtrain_minmax):
#     for i in range(x_train.shape[1]):
#         x_train[:, i] = (x_train[:, i] - xtrain_minmax[i, 0]) / (xtrain_minmax[i, 1] - xtrain_minmax[i, 0])

# y_train = get_binary(y_train)

# xtrain_minmax = np.zeros([x_train.shape[1], 2], np.float32)
# xtrain_minmax[:, 0] = np.min(x_train, axis=0)
# xtrain_minmax[:, 1] = np.max(x_train, axis=0)
# set_normxtrain(x_train, xtrain_minmax)
# pd.DataFrame(x_train).describe()

# xtrain_minmax = np.array([np.min(x_train), np.max(x_train)])
# x_train = normalization(x_train, *xtrain_minmax)

## x_train = np.concatenate((x_train, np.ones((x_train.shape[0], 1))), 1)

# %%
## get validation part

# percent_valid = 10
# border_valid = int(x_train.shape[0] * (100 - percent_valid) * 0.01)
# y_valid = y_train[border_valid:]
# x_valid = x_train[border_valid:]
# y_train = y_train[:border_valid]
# x_train = x_train[:border_valid]

# %%
arch = np.array([x_train.shape[1], 3, 4, 2], np.int8)
# arch = np.array([x_train.shape[1], 10, 6, 2], np.int8)
# arch = np.array([x_train.shape[1], 20, 8, 2], np.int8)
# arch = np.array([x_train.shape[1], 20, 12, 6, 2], np.int8)
# arch = np.array([x_train.shape[1], 3, 3, 2], np.int8)
# arch = np.array([x_train.shape[1], 4, 3, 2], np.int8)
# arch = np.array([x_train.shape[1], 8, 4, 2], np.int8)
# arch = np.array([x_train.shape[1], 7, 3, 2], np.int8)
# arch = np.array([x_train.shape[1], 6, 4, 2], np.int8)
# arch = np.array([x_train.shape[1], 3, 2], np.int8)
# arch = np.array([x_train.shape[1], 3, 4, 3, 2], np.int8)
# arch = np.array([x_train.shape[1], 30, 40, 20, 2], np.int8)

# f_act = "sigmoid"
# f_act = "hyptan"
f_act = "relu"

# %%
epochs = 200
alpha = 0.001
batch = 200

weight, error = learn_mp(x_train, y_train, arch, f_act, epochs, alpha, batch)

# %%
print(error)
plt.plot(range(epochs), error)
plt.xlabel('epochs')
plt.ylabel('error')
plt.grid()
plt.show()
# Out:
# [328.1598   310.61484  298.03906  287.33026  275.42902  263.87604
#  252.18452  239.62595  226.203    213.06802  198.9349   185.51779
#  172.59776  160.99303  151.12225  141.90408  133.92735  127.18654
#  120.69109  114.8723   110.070755 105.53993  101.70174   97.88237
#   95.16022   92.54436   90.67288   88.38252   86.75227   85.15553
#   83.59941   82.34359   81.349014  80.13484   79.26834   78.2202
#   77.240585  76.485115  76.17366   75.22421   74.409195  73.7437
#   73.300674  72.93148   72.32864   71.550705  71.36013   70.98465
#   70.46611   70.34426   70.2054    69.8611    69.260635  69.20332
#   68.970695  68.41141   68.1835    67.800186  67.51291   67.81392
#   67.6684    67.57748   66.62273   66.57867   66.495636  66.4245
#   66.5853    66.13282   65.732864  65.693344  65.22272   65.113106
#   65.03841   64.76404   65.396164  64.61653   64.60382   64.403046
#   64.0701    64.00832   64.368515  63.868248  64.07031   63.344624
#   63.507687  63.298443  63.3061    62.976315  62.978943  63.236954
#   63.112892  62.716953  62.490425  63.019157  62.922867  62.507095
#   62.26631   62.618446  62.359425  61.769096  63.014763  62.00295
#   61.765274  61.893322  61.317097  62.03978   61.59703   61.327427
#   61.670326  61.38842   61.223152  61.216557  61.159462  60.852592
#   60.68052   60.992374  60.650574  61.35084   60.78689   60.78277
#   60.627914  60.438187  60.490883  60.359665  60.513245  60.19262
#   60.703445  60.177692  60.320786  60.228878  60.42323   60.181507
#   60.66381   60.077873  59.886467  60.02544   59.741165  59.86284
#   59.698986  59.95677   59.793106  59.511333  61.171032  59.80873
#   59.961483  59.937237  59.69699   59.62178   59.579056  60.007816
#   59.41304   59.431778  59.424908  59.385246  59.290672  59.40123
#   59.83454   59.29772   59.695717  59.656166  60.024933  59.92062
#   59.302513  59.192955  59.427414  59.300888  59.265255  59.376175
#   59.228085  59.117943  59.36117   59.017445  59.36895   59.128662
#   59.26102   59.111023  59.44982   59.11268   58.970398  60.13835
#   59.06447   58.913986  59.111374  59.54935   59.048164  58.800102
#   58.922867  59.019417  58.99073   58.991684  59.95838   58.71241
#   58.98169   58.74218   58.972706  58.95308   59.130817  60.197502
#   58.909813  58.698696]
