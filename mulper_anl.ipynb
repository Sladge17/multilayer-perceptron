# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from mp_learn.settings import *
from mp_learn.train import *
from mp_learn.predict import *

# %%
df = pd.read_csv(dataset, header=None)
df.head(10)
# Out:
#          0  1      2      3       4       5        6        7        8   \
# 0    842302  M  17.99  10.38  122.80  1001.0  0.11840  0.27760  0.30010
# 1    842517  M  20.57  17.77  132.90  1326.0  0.08474  0.07864  0.08690
# 2  84300903  M  19.69  21.25  130.00  1203.0  0.10960  0.15990  0.19740
# 3  84348301  M  11.42  20.38   77.58   386.1  0.14250  0.28390  0.24140
# 4  84358402  M  20.29  14.34  135.10  1297.0  0.10030  0.13280  0.19800
# 5    843786  M  12.45  15.70   82.57   477.1  0.12780  0.17000  0.15780
# 6    844359  M  18.25  19.98  119.60  1040.0  0.09463  0.10900  0.11270
# 7  84458202  M  13.71  20.83   90.20   577.9  0.11890  0.16450  0.09366
# 8    844981  M  13.00  21.82   87.50   519.8  0.12730  0.19320  0.18590
# 9  84501001  M  12.46  24.04   83.97   475.9  0.11860  0.23960  0.22730
#
#         9   ...     22     23      24      25      26      27      28      29  \
# 0  0.14710  ...  25.38  17.33  184.60  2019.0  0.1622  0.6656  0.7119  0.2654
# 1  0.07017  ...  24.99  23.41  158.80  1956.0  0.1238  0.1866  0.2416  0.1860
# 2  0.12790  ...  23.57  25.53  152.50  1709.0  0.1444  0.4245  0.4504  0.2430
# 3  0.10520  ...  14.91  26.50   98.87   567.7  0.2098  0.8663  0.6869  0.2575
# 4  0.10430  ...  22.54  16.67  152.20  1575.0  0.1374  0.2050  0.4000  0.1625
# 5  0.08089  ...  15.47  23.75  103.40   741.6  0.1791  0.5249  0.5355  0.1741
# 6  0.07400  ...  22.88  27.66  153.20  1606.0  0.1442  0.2576  0.3784  0.1932
# 7  0.05985  ...  17.06  28.14  110.60   897.0  0.1654  0.3682  0.2678  0.1556
# 8  0.09353  ...  15.49  30.73  106.20   739.3  0.1703  0.5401  0.5390  0.2060
# 9  0.08543  ...  15.09  40.68   97.65   711.4  0.1853  1.0580  1.1050  0.2210
#
#        30       31
# 0  0.4601  0.11890
# 1  0.2750  0.08902
# 2  0.3613  0.08758
# 3  0.6638  0.17300
# 4  0.2364  0.07678
# 5  0.3985  0.12440
# 6  0.3063  0.08368
# 7  0.3196  0.11510
# 8  0.4378  0.10720
# 9  0.4366  0.20750
#
# [10 rows x 32 columns]

# %%
df.shape
# Out:
# (569, 32)

# %%
df.describe()
# Out:
#                  0           2           3           4            5   \
# count  5.690000e+02  569.000000  569.000000  569.000000   569.000000
# mean   3.037183e+07   14.127292   19.289649   91.969033   654.889104
# std    1.250206e+08    3.524049    4.301036   24.298981   351.914129
# min    8.670000e+03    6.981000    9.710000   43.790000   143.500000
# 25%    8.692180e+05   11.700000   16.170000   75.170000   420.300000
# 50%    9.060240e+05   13.370000   18.840000   86.240000   551.100000
# 75%    8.813129e+06   15.780000   21.800000  104.100000   782.700000
# max    9.113205e+08   28.110000   39.280000  188.500000  2501.000000
#
#                6           7           8           9           10  ...  \
# count  569.000000  569.000000  569.000000  569.000000  569.000000  ...
# mean     0.096360    0.104341    0.088799    0.048919    0.181162  ...
# std      0.014064    0.052813    0.079720    0.038803    0.027414  ...
# min      0.052630    0.019380    0.000000    0.000000    0.106000  ...
# 25%      0.086370    0.064920    0.029560    0.020310    0.161900  ...
# 50%      0.095870    0.092630    0.061540    0.033500    0.179200  ...
# 75%      0.105300    0.130400    0.130700    0.074000    0.195700  ...
# max      0.163400    0.345400    0.426800    0.201200    0.304000  ...
#
#                22          23          24           25          26  \
# count  569.000000  569.000000  569.000000   569.000000  569.000000
# mean    16.269190   25.677223  107.261213   880.583128    0.132369
# std      4.833242    6.146258   33.602542   569.356993    0.022832
# min      7.930000   12.020000   50.410000   185.200000    0.071170
# 25%     13.010000   21.080000   84.110000   515.300000    0.116600
# 50%     14.970000   25.410000   97.660000   686.500000    0.131300
# 75%     18.790000   29.720000  125.400000  1084.000000    0.146000
# max     36.040000   49.540000  251.200000  4254.000000    0.222600
#
#                27          28          29          30          31
# count  569.000000  569.000000  569.000000  569.000000  569.000000
# mean     0.254265    0.272188    0.114606    0.290076    0.083946
# std      0.157336    0.208624    0.065732    0.061867    0.018061
# min      0.027290    0.000000    0.000000    0.156500    0.055040
# 25%      0.147200    0.114500    0.064930    0.250400    0.071460
# 50%      0.211900    0.226700    0.099930    0.282200    0.080040
# 75%      0.339100    0.382900    0.161400    0.317900    0.092080
# max      1.058000    1.252000    0.291000    0.663800    0.207500
#
# [8 rows x 31 columns]

# %%
df.shape[0] - df.dropna().shape[0]
# Out:
# 0

# %%
df[1].unique()
# Out:
# array(['M', 'B'], dtype=object)

# %%
# percent_test = 20
border_test = int(df.shape[0] * (100 - percent_test) * 0.01)
df_train = df.iloc[:border_test]
df_test = df.iloc[border_test:]

# %%
y_train = df_train[1]
x_train = df_train[features]

# %%
tmp = pd.concat([y_train, x_train], axis=1)
tmp.columns = list(range(1 + x_train.shape[1]))
plt.scatter(tmp[tmp[0] == 'M'][1], tmp[tmp[0] == 'M'][2], s=10)
plt.scatter(tmp[tmp[0] == 'B'][1], tmp[tmp[0] == 'B'][2], s=10)
plt.ylabel('x1')
plt.grid()
plt.show()

# %%
x_train_mean = x_train.describe().T['mean']
x_train_std = x_train.describe().T['std']
x_train = (x_train - x_train_mean) / x_train_std

# %%
tmp = pd.concat([y_train, x_train], axis=1)
tmp.columns = list(range(1 + x_train.shape[1]))
plt.scatter(tmp[tmp[0] == 'M'][1], tmp[tmp[0] == 'M'][2], s=10)
plt.scatter(tmp[tmp[0] == 'B'][1], tmp[tmp[0] == 'B'][2], s=10)
plt.ylabel('x1')
plt.grid()
plt.show()

# %%
def get_binary(target):
    target = list(map(lambda x: [1, 0] if x == 'M' else [0, 1], target))
    target = np.array(target, np.int8)
    return target

y_train = get_binary(y_train)
x_train = x_train.values

# %%
# def normalization(target, val_min, val_max):
#     return (target - val_min) / (val_max - val_min)

# def set_normxtrain(x_train, xtrain_minmax):
#     for i in range(x_train.shape[1]):
#         x_train[:, i] = (x_train[:, i] - xtrain_minmax[i, 0]) / (xtrain_minmax[i, 1] - xtrain_minmax[i, 0])

# y_train = get_binary(y_train)

# xtrain_minmax = np.zeros([x_train.shape[1], 2], np.float32)
# xtrain_minmax[:, 0] = np.min(x_train, axis=0)
# xtrain_minmax[:, 1] = np.max(x_train, axis=0)
# set_normxtrain(x_train, xtrain_minmax)
# pd.DataFrame(x_train).describe()

# xtrain_minmax = np.array([np.min(x_train), np.max(x_train)])
# x_train = normalization(x_train, *xtrain_minmax)

## x_train = np.concatenate((x_train, np.ones((x_train.shape[0], 1))), 1)

# %%
## get validation part

# percent_valid = 10
# border_valid = int(x_train.shape[0] * (100 - percent_valid) * 0.01)
# y_valid = y_train[border_valid:]
# x_valid = x_train[border_valid:]
# y_train = y_train[:border_valid]
# x_train = x_train[:border_valid]

# %%
# arch = np.array([x_train.shape[1], 3, 4, 2], np.int8)
# arch = np.array([x_train.shape[1], 10, 6, 2], np.int8)
# arch = np.array([x_train.shape[1], 20, 8, 2], np.int8)
# arch = np.array([x_train.shape[1], 20, 12, 6, 2], np.int8)
# arch = np.array([x_train.shape[1], 3, 3, 2], np.int8)
# arch = np.array([x_train.shape[1], 4, 3, 2], np.int8)
# arch = np.array([x_train.shape[1], 5, 3, 2], np.int8)
# arch = np.array([x_train.shape[1], 8, 4, 2], np.int8)
# arch = np.array([x_train.shape[1], 7, 3, 2], np.int8)
# arch = np.array([x_train.shape[1], 6, 4, 2], np.int8)
# arch = np.array([x_train.shape[1], 3, 2], np.int8)
# arch = np.array([x_train.shape[1], 3, 4, 3, 2], np.int8)
# arch = np.array([x_train.shape[1], 30, 40, 20, 2], np.int8)

# f_act = "sigmoid"
# f_act = "hyptan"
# f_act = "relu"

# %%
arch = np.array([x_train.shape[1]] + arch, np.int8)

# %%
# epochs = 100
# alpha = 0.01
# # batch = x_train.shape[0]
# # batch = 1
# batch = 100
# # start_velocity = 0.6 ## maybe need always zero
# # start_velocity = 0.6 ## maybe need always zero
# start_velocity = 0.8 ## maybe need always zero
# start_velocity = 1.2 ## maybe need always zero

weight, error, accuracy = train_mp(x_train, y_train, arch, f_act, epochs, alpha, batch, start_velocity)

# %%
error[1]
# Out:
# array([33.15417  , 33.427994 , 33.308723 , 32.867664 , 32.26865  ,
#        31.567348 , 30.815083 , 30.047651 , 29.294111 , 28.607866 ,
#        27.987452 , 27.388132 , 26.794453 , 26.241747 , 25.69703  ,
#        25.149946 , 24.588219 , 23.985823 , 23.330074 , 22.66942  ,
#        21.983568 , 21.287846 , 20.533047 , 19.735933 , 18.909132 ,
#        18.118608 , 17.323042 , 16.561031 , 15.787925 , 15.016421 ,
#        14.277078 , 13.575967 , 12.904386 , 12.277083 , 11.701665 ,
#        11.19949  , 10.714544 , 10.269924 ,  9.848256 ,  9.458287 ,
#         9.170019 ,  8.916765 ,  8.6831045,  8.49518  ,  8.313077 ,
#         8.101588 ,  7.88146  ,  7.660258 ,  7.457091 ,  7.3578663,
#         7.275478 ,  7.2330704,  7.180903 ,  7.120463 ,  7.046753 ,
#         6.9627795,  6.8904586,  6.7720675,  6.6426454,  6.6039762,
#         6.5912786,  6.651858 ,  6.7023225,  6.735024 ,  6.749992 ,
#         6.8198657,  6.965534 ,  7.0502763,  7.147264 ,  7.161302 ,
#         7.091062 ,  7.0256805,  6.8582573,  6.6240554,  6.35549  ,
#         6.0429783,  5.722951 ,  5.3961883,  5.1601768,  4.9653616,
#         4.811392 ,  4.6641765,  4.558556 ,  4.4496427,  4.370162 ,
#         4.2794466,  4.1681185,  4.0833488,  4.0051436,  3.9403064,
#         3.893268 ,  3.842985 ,  3.8055024,  3.7521973,  3.6903872,
#         3.672584 ,  3.6698492,  3.7097495,  3.7254772,  3.7561944],
#       dtype=float32)

# %%
print(error[0])
# Out:
# [282.05057  285.3953   285.95383  284.5744   282.2277   279.32617
#  276.2472   273.2568   270.4982   268.03265  265.67545  263.31833
#  260.81635  257.998    254.76852  251.0171   246.70715  241.80432
#  236.37915  230.44868  223.94754  217.0198   209.60013  201.73972
#  193.53009  185.30331  176.96602  168.79303  160.86523  153.22063
#  145.9775   139.16547  132.86038  127.10747  121.830734 116.99117
#  112.55078  108.54786  104.897385 101.55507   98.41476   95.48436
#   92.71172   90.04882   87.46397   85.118576  82.952866  80.979126
#   79.05531   77.0351    75.08238   73.169205  71.474335  69.82753
#   68.2154    66.66598   65.047844  63.559967  62.126266  60.70363
#   59.3397    58.15181   57.11266   56.16896   55.300488  54.65256
#   54.266426  53.888794  53.66819   53.287846  52.68087   52.17579
#   51.363934  50.37604   49.313385  48.20312   47.214523  46.48358
#   46.02246   45.685867  45.387997  45.19616   44.942505  44.76944
#   44.534843  44.30594   44.12314   43.8507    43.5227    43.22731
#   42.68116   42.147236  41.435802  40.795315  40.16711   39.369873
#   38.57081   37.78752   37.159702  36.550095]

# %%
print(accuracy[0])
# Out:
# [42.787285 48.41076  48.16626  49.388752 53.54523  61.613693 68.704155
#  69.92665  62.591686 59.9022   58.924206 58.924206 58.679707 58.924206
#  59.168705 60.880196 62.836185 65.77017  69.19315  72.12714  76.283615
#  78.97311  81.17359  83.374084 84.84107  86.797066 88.50856  89.48655
#  89.48655  89.73105  90.953545 91.44254  91.44254  91.68704  90.953545
#  90.953545 91.44254  91.68704  91.68704  92.42054  92.66504  92.90954
#  92.90954  93.15404  93.15404  93.15404  93.39854  93.64303  93.64303
#  93.64303  93.64303  93.39854  93.39854  93.64303  93.88753  94.376526
#  94.376526 94.865524 94.865524 95.11002  95.35452  95.59902  95.84352
#  95.84352  95.84352  95.84352  95.84352  96.08802  96.08802  96.08802
#  95.84352  96.08802  96.08802  96.08802  96.08802  96.08802  95.84352
#  95.84352  96.08802  96.33252  96.33252  96.33252  96.33252  96.33252
#  96.33252  96.33252  96.33252  96.33252  96.33252  96.33252  96.57702
#  96.82152  96.57702  96.57702  96.57702  96.57702  96.57702  96.82152
#  96.57702  96.57702 ]

# %%
plt.plot(range(epochs), error[0])
plt.plot(range(epochs), accuracy[0])

plt.plot(range(epochs), error[1], linestyle='--', label='test')
plt.plot(range(epochs), accuracy[1], linestyle='--')
plt.xlabel('epochs')
plt.ylabel('error / accuracy')
plt.legend(loc='upper right')
plt.grid()
plt.show()

# %%
# y_test = df_test[1].values
y_test = df_test[1]
y_test = get_binary(y_test)
x_test = df_test[features]
x_test = ((x_test - x_train_mean) / x_train_std).values

# %%
prd = predict_mp(x_test, arch, f_act, weight)

# %%
acc = 0

# for i in range(prd.shape[0]):
#     if (np.argmax(prd[i]) == 0 and y_test[i] == "M") or\
#         (np.argmax(prd[i]) == 1 and y_test[i] == "B"):
#         acc += 1

for i in range(prd.shape[0]):
    if np.argmax(prd[i]) == np.argmax(y_test[i]):
        acc += 1

acc = acc / prd.shape[0] * 100
acc
# Out:
# 95.6140350877193
